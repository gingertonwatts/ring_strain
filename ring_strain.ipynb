# %%
# %% Run core-set ring strain and plot
import ring_strain_core as rs

# %%
# Compute ring strain for Gly4, Ala4, Val4 (HF / DFT / MP2)
# Set do_ccsd=True if you want to try CCSD as well.
results_df = rs.compute_strains_core_set(do_ccsd=False)

# Show the table of ring strain (kcal/mol)
display(results_df)

# Grouped bar chart: ring strain by method & system
rs.plot_grouped_bars(results_df)

# Method–method scatters
rs.plot_method_scatter(results_df, "DFT", "HF")
#rs.plot_method_scatter(results_df, "HF", "MP2")
# Out:
# === Building system Gly4 ===
#
# === Building system Ala4 ===
#
# === Building system Val4 ===
#
# ################ Gly4 ################
#
# === Gly4 (cyc): DFT (wb97x/def2-svp) ===
# converged SCF energy = -831.23846525045
# Gly4 (cyc) DFT energy: -831.2384652504 Ha
#
# === Gly4 (ref): DFT (wb97x/def2-svp) ===
# converged SCF energy = -1079.45982858242
# Gly4 (ref) DFT energy: -1079.4598285824 Ha
#
# === Gly4 (cyc): HF (def2-svp) ===
# converged SCF energy = -826.60374704836
# Gly4 (cyc) HF energy: -826.6037470484 Ha
#
# === Gly4 (ref): HF (def2-svp) ===
# converged SCF energy = -1073.35201672161
# Gly4 (ref) HF energy: -1073.3520167216 Ha
#
# Ring strain for Gly4 (kcal/mol):
#   HF  : 154836.88
#   DFT : 155761.26
#
# ################ Ala4 ################
#
# === Ala4 (cyc): DFT (wb97x/def2-svp) ===
# converged SCF energy = -988.376687880579
# Ala4 (cyc) DFT energy: -988.3766878806 Ha
#
# === Ala4 (ref): DFT (wb97x/def2-svp) ===
# converged SCF energy = -1236.59024464903
# ...

# %%
results_df
# Out:
#                    HF            DFT
# system
# Gly4    154836.876913  155761.257140
# Ala4    154836.239704  155756.358447
# Val4    154896.592105  155807.902530
