# %% [markdown]
# # Ring strain workflow (All sizes): PySCF DFT + PCM
# This notebook loads structures saved by `ring_strain_generate_all_sizes.ipynb` and computes
# T=0 K electronic energies using **PySCF DFT + PCM** (no dispersion).
#
# We compute
# \[E_{\mathrm{strain}}(b) = (E(M_{\mathrm{open}})-E(M)) - (E(X_{\mathrm{open}})-E(X)).\]
#
# Solvent: DMF by default (ε = 36.7), changeable below.
#
# Implementation note: this notebook uses your preferred pattern `mf = dft.RKS(mol); mf = mf.PCM();`
# and falls back to `from pyscf.solvent import pcm; mf = pcm.PCM(mf)` if `.PCM()` is unavailable.

# %%
from pathlib import Path
import json
import numpy as np
import pandas as pd
import rdkit
print('RDKit', rdkit.__version__)
# Out:
# RDKit 2025.09.3

# %%
from pyscf import gto, dft
print('PySCF imported')
# Out:
# PySCF imported

# %% [markdown]
# ## 1) Load manifest and choose what to run

# %%
out_root = Path('ring_strain_outputs_all_sizes')
manifest_path = out_root / 'manifest.json'
manifest = json.loads(manifest_path.read_text())
print('Loaded entries:', len(manifest))

# Filter: run only a specific ring (set to None to run all entries)
RING_FILTER = None  # e.g. 'medium_cyclododecane'
to_run = [e for e in manifest if (RING_FILTER is None or e['ring'] == RING_FILTER)]
print('Entries to run:', len(to_run))
# Out:
# Loaded entries: 3
# Entries to run: 3

# %% [markdown]
# ## 2) DFT + PCM settings

# %%
# DFT settings
xc = 'b3lyp'          # user-preferred default; try 'pbe0' as a no-dispersion alternative
basis = 'def2-svp'    # as requested
charge = 0
spin = 0              # 2S

# Solvent settings
pcm_method = 'IEF-PCM'   # options depend on your PySCF build; IEF-PCM is a safe default
eps = 36.7               # DMF dielectric; set 78.3553 for water

# SCF controls
max_cycle = 200
conv_tol = 1e-9

# %% [markdown]
# ## 3) Read XYZ (first frame) -> PySCF atom string

# %%
def read_xyz_first_frame(xyz_path: Path):
    lines = xyz_path.read_text().splitlines()
    n = int(lines[0].strip())
    comment = lines[1].strip()
    atoms = []
    for ln in lines[2:2+n]:
        s, x, y, z = ln.split()[:4]
        atoms.append((s, float(x), float(y), float(z)))
    return comment, atoms

def atoms_to_pyscf_atom(atoms):
    return '\n'.join([f"{s} {x} {y} {z}" for (s,x,y,z) in atoms])

# %% [markdown]
# ## 4) Single-point DFT + PCM energy (your PCM pattern + fallback)

# %%
def attach_pcm(mf, method: str, eps: float):
    """Attach PCM using mf.PCM() when available; otherwise fall back to pcm.PCM(mf)."""
    if hasattr(mf, 'PCM'):
        mf2 = mf.PCM()
    else:
        from pyscf.solvent import pcm
        mf2 = pcm.PCM(mf)
    mf2.with_solvent.method = method
    mf2.with_solvent.eps = float(eps)
    return mf2

def dft_pcm_energy(xyz_path: Path,
                   xc: str, basis: str, charge: int, spin: int,
                   pcm_method: str, eps: float,
                   max_cycle: int = 200, conv_tol: float = 1e-9):
    comment, atoms = read_xyz_first_frame(xyz_path)
    mol = gto.M(
        atom=atoms_to_pyscf_atom(atoms),
        basis=basis,
        charge=charge,
        spin=spin,
        unit='Angstrom',
        verbose=0,
    )
    mf = dft.RKS(mol)
    mf.xc = xc
    mf.max_cycle = max_cycle
    mf.conv_tol = conv_tol
    mf = attach_pcm(mf, method=pcm_method, eps=eps)
    e = mf.kernel()
    return float(e), comment

# %% [markdown]
# ## 5) Run energies and compute strain

# %%
HARTREE_TO_KCALMOL = 627.509474

rows = []
for e in to_run:
    ring = e['ring']
    bond_tag = e['bond_tag']
    bond_idx = e['bond_idx']

    energies = {}
    for sp in ['M','M_open','X','X_open']:
        xyz_path = Path(e['species'][sp]['xyz'])
        # handle relative paths
        if not xyz_path.exists():
            xyz_path = out_root / xyz_path
        E, _ = dft_pcm_energy(
            xyz_path,
            xc=xc, basis=basis, charge=charge, spin=spin,
            pcm_method=pcm_method, eps=eps,
            max_cycle=max_cycle, conv_tol=conv_tol,
        )
        energies[sp] = E
        print(f"{ring} {bond_tag} {sp}: E = {E:.10f} Ha")

    E_strain = (energies['M_open'] - energies['M']) - (energies['X_open'] - energies['X'])

    rows.append({
        'ring': ring,
        'bond_tag': bond_tag,
        'bond_idx': bond_idx,
        'xc': xc,
        'basis': basis,
        'pcm_method': pcm_method,
        'eps': eps,
        'E_M': energies['M'],
        'E_M_open': energies['M_open'],
        'E_X': energies['X'],
        'E_X_open': energies['X_open'],
        'E_strain_Ha': E_strain,
        'E_strain_kcalmol': E_strain * HARTREE_TO_KCALMOL,
    })

df = pd.DataFrame(rows).sort_values(['ring','bond_idx']).reset_index(drop=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 15
#      13 if not xyz_path.exists():
#      14     xyz_path = out_root / xyz_path
# ---> 15 E, _ = dft_pcm_energy(
#      16     xyz_path,
#      17     xc=xc, basis=basis, charge=charge, spin=spin,
#      18     pcm_method=pcm_method, eps=eps,
#      19     max_cycle=max_cycle, conv_tol=conv_tol,
#      20 )
#      21 energies[sp] = E
#      22 print(f"{ring} {bond_tag} {sp}: E = {E:.10f} Ha")
#
# Cell In[6], line 30, in dft_pcm_energy(xyz_path, xc, basis, charge, spin, pcm_method, eps, max_cycle, conv_tol)
#      28 mf.conv_tol = conv_tol
#      29 mf = attach_pcm(mf, method=pcm_method, eps=eps)
# ---> 30 e = mf.kernel()
#      31 return float(e), comment
#
# File <string>:2, in kernel(self, dm0, **kwargs)
#
# File ~/miniconda3/envs/dvr_H/lib/python3.12/site-packages/pyscf/scf/hf.py:2018, in SCF.scf(self, dm0, **kwargs)
#    2013     dm0 = self.make_rdm1()
#    2015 if self.max_cycle > 0 or self.mo_coeff is None:
#    2016     self.converged, self.e_tot, \
#    2017             self.mo_energy, self.mo_coeff, self.mo_occ = \
# -> 2018             kernel(self, self.conv_tol, self.conv_tol_grad,
#    2019                    dm0=dm0, callback=self.callback,
#    2020                    conv_check=self.conv_check, **kwargs)
#    2021 else:
#    2022     # Avoid to update SCF orbitals in the non-SCF initialization
#    2023     # (issue #495).  But run regular SCF for initial guess if SCF was
#    2024     # not initialized.
#    2025     self.e_tot = kernel(self, self.conv_tol, self.conv_tol_grad,
#    2026                         dm0=dm0, callback=self.callback,
#    2027                         conv_check=self.conv_check, **kwargs)[1]
#
# File ~/miniconda3/envs/dvr_H/lib/python3.12/site-packages/pyscf/scf/hf.py:129, in kernel(mf, conv_tol, conv_tol_grad, dump_chk, dm0, callback, conv_check, **kwargs)
#     126     dm = dm0
#     128 h1e = mf.get_hcore(mol)
# --> 129 vhf = mf.get_veff(mol, dm)
#     130 e_tot = mf.energy_tot(dm, h1e, vhf)
#     131 logger.info(mf, 'init E= %.15g', e_tot)
#
# File ~/miniconda3/envs/dvr_H/lib/python3.12/site-packages/pyscf/solvent/_attach_solvent.py:88, in SCFWithSolvent.get_veff(self, mol, dm, *args, **kwargs)
#      86 with_solvent = self.with_solvent
#      87 if not with_solvent.frozen:
# ---> 88     with_solvent.e, with_solvent.v = with_solvent.kernel(dm)
#      89 e_solvent, v_solvent = with_solvent.e, with_solvent.v
#      91 # NOTE: v_solvent should not be added to vhf in this place. This is
#      92 # because vhf is used as the reference for direct_scf in the next
#      93 # iteration. If v_solvent is added here, it may break direct SCF.
#
# File ~/miniconda3/envs/dvr_H/lib/python3.12/site-packages/pyscf/solvent/ddcosmo.py:764, in ddCOSMO.kernel(self, dm)
#     761 '''A single shot solvent effects for given density matrix.
#     762 '''
#     763 self._dm = dm
# --> 764 self.e, self.v = self._get_vind(dm)
#     765 logger.info(self, '%s E_diel = %.15g', self.__class__.__name__, self.e)
#     766 return self.e, self.v
#
# File ~/miniconda3/envs/dvr_H/lib/python3.12/site-packages/pyscf/solvent/pcm.py:440, in PCM._get_vind(self, dms)
#     438 def _get_vind(self, dms):
#     439     if not self._intermediates:
# --> 440         self.build()
#     442     nao = dms.shape[-1]
#     443     dms = dms.reshape(-1,nao,nao)
#
# File ~/miniconda3/envs/dvr_H/lib/python3.12/site-packages/pyscf/solvent/pcm.py:391, in PCM.build(self, ng)
#     389 self._intermediates = {}
#     390 F, A = get_F_A(self.surface)
# --> 391 D, S = get_D_S(self.surface, with_S=True, with_D=True)
#     393 epsilon = self.eps
#     394 if self.method.upper() in ['C-PCM', 'CPCM']:
#
# File ~/miniconda3/envs/dvr_H/lib/python3.12/site-packages/pyscf/solvent/pcm.py:225, in get_D_S(surface, with_S, with_D)
#     223 xi_i, xi_j = numpy.meshgrid(charge_exp, charge_exp, indexing='ij')
#     224 xi_ij = xi_i * xi_j / (xi_i**2 + xi_j**2)**0.5
# --> 225 rij = scipy.spatial.distance.cdist(grid_coords, grid_coords)
#     226 xi_r_ij = xi_ij * rij
#     227 numpy.fill_diagonal(rij, 1)
#
# File ~/miniconda3/envs/dvr_H/lib/python3.12/site-packages/scipy/spatial/distance.py:3134, in cdist(XA, XB, metric, out, **kwargs)
#    3132 if metric_info is not None:
#    3133     cdist_fn = metric_info.cdist_func
# -> 3134     return cdist_fn(XA, XB, out=out, **kwargs)
#    3135 elif mstr.startswith("test_"):
#    3136     metric_info = _TEST_METRICS.get(mstr, None)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 6) Save results

# %%
results_path = out_root / 'dft_pcm_results.csv'
df.to_csv(results_path, index=False)
print('Saved:', results_path.resolve())

# %% [markdown]
# ## Optional: geometry optimization
# If you want to optimize geometries in PySCF, you can use `pyscf.geomopt.geometric_solver`.
# This is optional and can be expensive for larger systems.

# %%
# from pyscf.geomopt.geometric_solver import optimize
#
# def optimize_dft_pcm(xyz_path: Path, xc: str, basis: str, charge: int, spin: int,
#                      pcm_method: str, eps: float):
#     comment, atoms = read_xyz_first_frame(xyz_path)
#     mol = gto.M(atom=atoms_to_pyscf_atom(atoms), basis=basis, charge=charge, spin=spin, unit='Angstrom', verbose=4)
#     mf = dft.RKS(mol)
#     mf.xc = xc
#     mf = attach_pcm(mf, method=pcm_method, eps=eps)
#     mol_opt = optimize(mf)
#     return mol_opt
#
# # Example:
# # mol_opt = optimize_dft_pcm(Path(to_run[0]['species']['M']['xyz']), xc, basis, charge, spin, pcm_method, eps)
